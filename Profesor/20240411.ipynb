# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
names = lambda obj: print([name for name in dir(obj) if name[0] != "_"])

# %%
a = np.array([2, 4, 6, 8])
a
# Out:
# array([2, 4, 6, 8])

# %%
a.dtype
# Out:
# dtype('int32')

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (4,)

# %%
np.random.randint(10, 20, (3, 4))
# Out:
# array([[16, 15, 11, 13],
#        [19, 12, 10, 10],
#        [14, 11, 13, 15]])

# %%
names(np.random)
# Out:
# ['BitGenerator', 'Generator', 'MT19937', 'PCG64', 'PCG64DXSM', 'Philox', 'RandomState', 'SFC64', 'SeedSequence', 'beta', 'binomial', 'bit_generator', 'bytes', 'chisquare', 'choice', 'default_rng', 'dirichlet', 'exponential', 'f', 'gamma', 'geometric', 'get_bit_generator', 'get_state', 'gumbel', 'hypergeometric', 'laplace', 'logistic', 'lognormal', 'logseries', 'mtrand', 'multinomial', 'multivariate_normal', 'negative_binomial', 'noncentral_chisquare', 'noncentral_f', 'normal', 'pareto', 'permutation', 'poisson', 'power', 'rand', 'randint', 'randn', 'random', 'random_integers', 'random_sample', 'ranf', 'rayleigh', 'sample', 'seed', 'set_bit_generator', 'set_state', 'shuffle', 'standard_cauchy', 'standard_exponential', 'standard_gamma', 'standard_normal', 'standard_t', 'test', 'triangular', 'uniform', 'vonmises', 'wald', 'weibull', 'zipf']

# %%
generator = np.random.Generator(np.random.PCG64())

# %%
names(generator)
# Out:
# ['beta', 'binomial', 'bit_generator', 'bytes', 'chisquare', 'choice', 'dirichlet', 'exponential', 'f', 'gamma', 'geometric', 'gumbel', 'hypergeometric', 'integers', 'laplace', 'logistic', 'lognormal', 'logseries', 'multinomial', 'multivariate_hypergeometric', 'multivariate_normal', 'negative_binomial', 'noncentral_chisquare', 'noncentral_f', 'normal', 'pareto', 'permutation', 'permuted', 'poisson', 'power', 'random', 'rayleigh', 'shuffle', 'spawn', 'standard_cauchy', 'standard_exponential', 'standard_gamma', 'standard_normal', 'standard_t', 'triangular', 'uniform', 'vonmises', 'wald', 'weibull', 'zipf']

# %%
np.random.randint(10, 20, 5)
# Out:
# array([13, 10, 12, 17, 19])

# %%
generator.integers(10, 20, 5)
# Out:
# array([16, 12, 10, 17, 17], dtype=int64)

# %%
a = generator.integers(10, 20, 5)
a
# Out:
# array([10, 14, 12, 14, 19], dtype=int64)

# %%
a[-1]
# Out:
# 19

# %%
a[2:4]
# Out:
# array([12, 14], dtype=int64)

# %%
a = generator.integers(0, 20, size = (4, 5))
a
# Out:
# array([[15,  6, 18,  5, 16],
#        [ 4, 10,  3, 12,  0],
#        [18, 13,  2,  6, 15],
#        [18,  5, 17,  1, 16]], dtype=int64)

# %%
a.shape
# Out:
# (4, 5)

# %%
a[1:3, 1:4]
# Out:
# array([[10,  3, 12],
#        [13,  2,  6]], dtype=int64)

# %%
sunset = plt.imread("sunset.png")

# %%
type(sunset)
# Out:
# numpy.ndarray

# %%
sunset.ndim
# Out:
# 3

# %%
sunset.shape
# Out:
# (600, 800, 4)

# %%
plt.imshow(sunset);

# %%
sunset.max()
# Out:
# 1.0

# %%
sunset.min()
# Out:
# 0.0

# %%
a
# Out:
# array([[15,  6, 18,  5, 16],
#        [ 4, 10,  3, 12,  0],
#        [18, 13,  2,  6, 15],
#        [18,  5, 17,  1, 16]], dtype=int64)

# %%
a.flatten()
# Out:
# array([15,  6, 18,  5, 16,  4, 10,  3, 12,  0, 18, 13,  2,  6, 15, 18,  5,
#        17,  1, 16], dtype=int64)

# %%
plt.hist(a.flatten(), bins = 20);

# %%
plt.hist(sunset.flatten(), bins = 50);

# %%
plt.hist(sunset[:, :, :3].flatten(), bins = 50);

# %%
b = sunset.copy()

# %%
plt.imshow(b);

# %%
plt.hist(b[:, :, -1].flatten(), bins = 50);

# %%
a
# Out:
# array([[15,  6, 18,  5, 16],
#        [ 4, 10,  3, 12,  0],
#        [18, 13,  2,  6, 15],
#        [18,  5, 17,  1, 16]], dtype=int64)

# %%
a[2, 1] = -1

# %%
a
# Out:
# array([[15,  6, 18,  5, 16],
#        [ 4, 10,  3, 12,  0],
#        [18, -1,  2,  6, 15],
#        [18,  5, 17,  1, 16]], dtype=int64)

# %%
a[1:3, 1:3] = -11

# %%
a
# Out:
# array([[ 15,   6,  18,   5,  16],
#        [  4, -11, -11,  12,   0],
#        [ 18, -11, -11,   6,  15],
#        [ 18,   5,  17,   1,  16]], dtype=int64)

# %%
plt.imshow(b);

# %%
b[200:400, :, -1] = 0.5

# %%
plt.imshow(b);

# %%
sun = b[480:520, 450:500]

# %%
plt.imshow(sun);

# %%
plt.imshow(sunset);

# %%
red = sunset[:, :, 0]

# %%
red.ndim
# Out:
# 2

# %%
plt.imshow(red, cmap = "gray");

# %%
import math

# %%
n = 1000000
m = [generator.random() for _ in range(n)]

# %%
# %%timeit
p = []
for v in m:
    p.append(math.log(v))
# Out:
# 378 ms ± 61.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
p = [math.log(v) for v in m]
# Out:
# 375 ms ± 55.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
m = np.array(m)

# %%
# %%timeit
p = np.log(m)
# Out:
# 17.1 ms ± 3.84 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
a
# Out:
# array([[ 15,   6,  18,   5,  16],
#        [  4, -11, -11,  12,   0],
#        [ 18, -11, -11,   6,  15],
#        [ 18,   5,  17,   1,  16]], dtype=int64)

# %%
a = generator.integers(1, 10, size = (4, 6))
a
# Out:
# array([[6, 1, 7, 9, 4, 1],
#        [8, 1, 5, 6, 2, 6],
#        [2, 2, 3, 7, 9, 8],
#        [9, 1, 3, 3, 9, 7]], dtype=int64)

# %%
np.log(a)
# Out:
# array([[1.79175947, 0.        , 1.94591015, 2.19722458, 1.38629436,
#         0.        ],
#        [2.07944154, 0.        , 1.60943791, 1.79175947, 0.69314718,
#         1.79175947],
#        [0.69314718, 0.69314718, 1.09861229, 1.94591015, 2.19722458,
#         2.07944154],
#        [2.19722458, 0.        , 1.09861229, 1.09861229, 2.19722458,
#         1.94591015]])

# %%
b = generator.integers(1, 10, size = (4, 6))
b
# Out:
# array([[8, 9, 1, 3, 3, 5],
#        [2, 1, 4, 3, 5, 7],
#        [8, 2, 7, 6, 7, 1],
#        [3, 7, 8, 9, 8, 1]], dtype=int64)

# %%
np.add(a, b) # Element wise
# Out:
# array([[14, 10,  8, 12,  7,  6],
#        [10,  2,  9,  9,  7, 13],
#        [10,  4, 10, 13, 16,  9],
#        [12,  8, 11, 12, 17,  8]], dtype=int64)

# %%
np.subtract(a, b)
# Out:
# array([[-2, -8,  6,  6,  1, -4],
#        [ 6,  0,  1,  3, -3, -1],
#        [-6,  0, -4,  1,  2,  7],
#        [ 6, -6, -5, -6,  1,  6]], dtype=int64)

# %%
np.multiply(a, b)
# Out:
# array([[48,  9,  7, 27, 12,  5],
#        [16,  1, 20, 18, 10, 42],
#        [16,  4, 21, 42, 63,  8],
#        [27,  7, 24, 27, 72,  7]], dtype=int64)

# %%
np.sqrt(a)
# Out:
# array([[2.44948974, 1.        , 2.64575131, 3.        , 2.        ,
#         1.        ],
#        [2.82842712, 1.        , 2.23606798, 2.44948974, 1.41421356,
#         2.44948974],
#        [1.41421356, 1.41421356, 1.73205081, 2.64575131, 3.        ,
#         2.82842712],
#        [3.        , 1.        , 1.73205081, 1.73205081, 3.        ,
#         2.64575131]])

# %%
np.square(a)
# Out:
# array([[36,  1, 49, 81, 16,  1],
#        [64,  1, 25, 36,  4, 36],
#        [ 4,  4,  9, 49, 81, 64],
#        [81,  1,  9,  9, 81, 49]], dtype=int64)

# %%
np.sin(a)
# Out:
# array([[-0.2794155 ,  0.84147098,  0.6569866 ,  0.41211849, -0.7568025 ,
#          0.84147098],
#        [ 0.98935825,  0.84147098, -0.95892427, -0.2794155 ,  0.90929743,
#         -0.2794155 ],
#        [ 0.90929743,  0.90929743,  0.14112001,  0.6569866 ,  0.41211849,
#          0.98935825],
#        [ 0.41211849,  0.84147098,  0.14112001,  0.14112001,  0.41211849,
#          0.6569866 ]])

# %%
a
# Out:
# array([[6, 1, 7, 9, 4, 1],
#        [8, 1, 5, 6, 2, 6],
#        [2, 2, 3, 7, 9, 8],
#        [9, 1, 3, 3, 9, 7]], dtype=int64)

# %%
b
# Out:
# array([[8, 9, 1, 3, 3, 5],
#        [2, 1, 4, 3, 5, 7],
#        [8, 2, 7, 6, 7, 1],
#        [3, 7, 8, 9, 8, 1]], dtype=int64)

# %%
np.equal(a, b)
# Out:
# array([[False, False, False, False, False, False],
#        [False,  True, False, False, False, False],
#        [False,  True, False, False, False, False],
#        [False, False, False, False, False, False]])

# %%
np.greater(a, b)
# Out:
# array([[False, False,  True,  True,  True, False],
#        [ True, False,  True,  True, False, False],
#        [False, False, False,  True,  True,  True],
#        [ True, False, False, False,  True,  True]])

# %%
np.greater_equal(a, b)
# Out:
# array([[False, False,  True,  True,  True, False],
#        [ True,  True,  True,  True, False, False],
#        [False,  True, False,  True,  True,  True],
#        [ True, False, False, False,  True,  True]])

# %%
np.less(a, b)
# Out:
# array([[ True,  True, False, False, False,  True],
#        [False, False, False, False,  True,  True],
#        [ True, False,  True, False, False, False],
#        [False,  True,  True,  True, False, False]])

# %%
plt.imshow(sunset);

# %%
a
# Out:
# array([[6, 1, 7, 9, 4, 1],
#        [8, 1, 5, 6, 2, 6],
#        [2, 2, 3, 7, 9, 8],
#        [9, 1, 3, 3, 9, 7]], dtype=int64)

# %%
np.divide(a, 2)
# Out:
# array([[3. , 0.5, 3.5, 4.5, 2. , 0.5],
#        [4. , 0.5, 2.5, 3. , 1. , 3. ],
#        [1. , 1. , 1.5, 3.5, 4.5, 4. ],
#        [4.5, 0.5, 1.5, 1.5, 4.5, 3.5]])

# %%
a / 2
# Out:
# array([[3. , 0.5, 3.5, 4.5, 2. , 0.5],
#        [4. , 0.5, 2.5, 3. , 1. , 3. ],
#        [1. , 1. , 1.5, 3.5, 4.5, 4. ],
#        [4.5, 0.5, 1.5, 1.5, 4.5, 3.5]])

# %%
plt.imshow(sunset[:, :, :3] / 2);

# %%
a
# Out:
# array([[6, 1, 7, 9, 4, 1],
#        [8, 1, 5, 6, 2, 6],
#        [2, 2, 3, 7, 9, 8],
#        [9, 1, 3, 3, 9, 7]], dtype=int64)

# %%
b
# Out:
# array([[8, 9, 1, 3, 3, 5],
#        [2, 1, 4, 3, 5, 7],
#        [8, 2, 7, 6, 7, 1],
#        [3, 7, 8, 9, 8, 1]], dtype=int64)

# %%
np.concatenate((a, b), axis = 0)
# Out:
# array([[6, 1, 7, 9, 4, 1],
#        [8, 1, 5, 6, 2, 6],
#        [2, 2, 3, 7, 9, 8],
#        [9, 1, 3, 3, 9, 7],
#        [8, 9, 1, 3, 3, 5],
#        [2, 1, 4, 3, 5, 7],
#        [8, 2, 7, 6, 7, 1],
#        [3, 7, 8, 9, 8, 1]], dtype=int64)

# %%
np.concatenate((a, b), axis = 1)
# Out:
# array([[6, 1, 7, 9, 4, 1, 8, 9, 1, 3, 3, 5],
#        [8, 1, 5, 6, 2, 6, 2, 1, 4, 3, 5, 7],
#        [2, 2, 3, 7, 9, 8, 8, 2, 7, 6, 7, 1],
#        [9, 1, 3, 3, 9, 7, 3, 7, 8, 9, 8, 1]], dtype=int64)

# %%
dog = plt.imread("dog.jpg")

# %%
plt.imshow(dog);

# %%
dog.ndim
# Out:
# 3

# %%
plt.imshow(np.concatenate((sunset[:, :, :3], dog), axis = 0));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
sunset.shape
# Out:
# (600, 800, 4)

# %%
dog.shape
# Out:
# (600, 800, 3)

# %%
sunset[:, :, :3].shape
# Out:
# (600, 800, 3)

# %%
dog / 255
# Out:
# array([[[0.84313725, 0.82745098, 0.79215686],
#         [0.84705882, 0.83137255, 0.79607843],
#         [0.84705882, 0.83137255, 0.79607843],
#         ...,
#         [0.9372549 , 0.92156863, 0.90980392],
#         [0.9372549 , 0.92156863, 0.90980392],
#         [0.93333333, 0.91764706, 0.90588235]],
#
#        [[0.84705882, 0.83137255, 0.79607843],
#         [0.85098039, 0.83529412, 0.8       ],
#         [0.85490196, 0.83921569, 0.80392157],
#         ...,
#         [0.9372549 , 0.92156863, 0.90980392],
#         [0.9372549 , 0.92156863, 0.90980392],
#         [0.93333333, 0.91764706, 0.90588235]],
#
#        [[0.84705882, 0.83137255, 0.79607843],
#         [0.85098039, 0.83137255, 0.80784314],
#         [0.85882353, 0.83921569, 0.81568627],
#         ...,
#         [0.9372549 , 0.92156863, 0.90980392],
#         [0.9372549 , 0.92156863, 0.90980392],
#         [0.9372549 , 0.92156863, 0.90980392]],
#
#        ...,
#
#        [[0.99215686, 0.96078431, 0.90980392],
# ...

# %%
1 / 255
# Out:
# 0.00392156862745098

# %%
plt.imshow(np.concatenate((sunset[:, :, :3], dog / 255), axis = 0));

# %%
(sunset[:, :, :3] * 255).astype("int")
# Out:
# array([[[ 89, 100, 122],
#         [ 89, 100, 121],
#         [ 92, 102, 123],
#         ...,
#         [ 96, 110, 133],
#         [ 99, 109, 134],
#         [100, 109, 136]],
#
#        [[ 92, 101, 123],
#         [ 90, 100, 121],
#         [ 90, 101, 121],
#         ...,
#         [ 97, 110, 132],
#         [ 99, 109, 132],
#         [100, 109, 133]],
#
#        [[ 93, 102, 123],
#         [ 93, 103, 121],
#         [ 91, 102, 121],
#         ...,
#         [100, 111, 133],
#         [101, 111, 132],
#         [101, 111, 133]],
#
#        ...,
#
#        [[  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3],
#         ...,
#         [ 89,  89,  87],
#         [ 86,  86,  84],
#         [ 90,  90,  91]],
#
#        [[  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3],
#         ...,
#         [ 90,  91,  91],
#         [ 89,  89,  89],
#         [ 77,  77,  79]],
#
#        [[  4,   4,   4],
#         [  3,   3,   3],
#         [  3,   3,   3],
# ...

# %%
plt.imshow(np.concatenate(((sunset[:, :, :3] * 255).astype("int"), dog), axis = 0));

# %%
from scipy.io import wavfile

# %%
names(wavfile)
# Out:
# ['IntEnum', 'KNOWN_WAVE_FORMATS', 'WAVE_FORMAT', 'WavFileWarning', 'io', 'numpy', 'read', 'struct', 'sys', 'warnings', 'write']

# %%
freq, data = wavfile.read("toy_story.wav")

# %%
freq
# Out:
# 44100

# %%
data.dtype
# Out:
# dtype('int16')

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (264431, 2)

# %%
data.shape[0] / freq
# Out:
# 5.996167800453515

# %%
data
# Out:
# array([[    0,     0],
#        [    0,     0],
#        [    0,     0],
#        ...,
#        [-2309, -2759],
#        [-1436, -2033],
#        [ -594, -1332]], dtype=int16)

# %%
left = data[:, 0]
right = data[:, 1]

# %%
left
# Out:
# array([    0,     0,     0, ..., -2309, -1436,  -594], dtype=int16)

# %%
plt.plot(left);

# %%
plt.plot(right);

# %% [markdown]
# # Pandas

# %%
lisboa = np.array([2, 4, 5])
madrid = np.array([1, 4, 3])

# %%
lisboa + madrid
# Out:
# array([3, 8, 8])

# %% [markdown]
# * Series: 1d, se basan en un array NumPy de 1d
# * DataFrame: 2d, se basan en arrays NumPy de 1d

# %%
import pandas as pd

# %%
pd.Series([2, 4, 6, 8, 10])
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
lisboa = pd.Series([2, 4, 6], index = ["ene", "feb", "mar"])
lisboa
# Out:
# ene    2
# feb    4
# mar    6
# dtype: int64

# %%
madrid = pd.Series([3, 2, 3], index = ["mar", "ene", "feb"])
madrid
# Out:
# mar    3
# ene    2
# feb    3
# dtype: int64

# %%
lisboa + madrid
# Out:
# ene    4
# feb    7
# mar    9
# dtype: int64

# %%
a = pd.Series([2, 4, 6])
a
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
b = pd.Series([3, 2, 3])
b
# Out:
# 0    3
# 1    2
# 2    3
# dtype: int64

# %%
a + b
# Out:
# 0    5
# 1    6
# 2    9
# dtype: int64

# %%
pd.DataFrame(data = generator.integers(0, 10, size = (4, 6)))
# Out:
#    0  1  2  3  4  5
# 0  8  3  3  5  3  1
# 1  7  3  4  4  5  3
# 2  1  3  7  2  4  7
# 3  7  6  4  3  5  6

# %%
pd.DataFrame(
    data = generator.integers(0, 10, size = (4, 6)),
    index = ["ene", "feb", "mar", "abr"]
)
# Out:
#      0  1  2  3  4  5
# ene  5  2  0  6  6  8
# feb  6  5  5  9  4  5
# mar  0  3  9  7  3  3
# abr  6  9  4  9  9  3

# %%
data = pd.DataFrame(
    data = generator.integers(0, 10, size = (4, 6)),
    index = ["ene", "feb", "mar", "abr"],
    columns = list("ABCDEF")
)
data
# Out:
#      A  B  C  D  E  F
# ene  4  2  7  7  7  9
# feb  6  1  1  9  4  3
# mar  4  8  1  8  1  6
# abr  8  7  6  3  7  0

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...
