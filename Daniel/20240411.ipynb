# %%
import numpy as np #importacion numpy
import matplotlib.pyplot as plt #importacion matplotlib

# %%
names = lambda obj: print([name for name in dir(obj) if name[0] != "_"])

# %%
a = np.array([2, 4, 6, 8]) #array numpy
a
# Out:
# array([2, 4, 6, 8])

# %%
a.dtype #tipo de los valores contenidos en el array
#array numpy solo puede contener valores de un unico tipo
#enteros de 32 bits, de 64bit, floats, textos, complex, etc. Un solo tipo
# Out:
# dtype('int64')

# %%
a.ndim #nº Dimensiones del array
# Out:
# 1

# %%
a.shape
#devuelve tupla que contiene nº de valores que en cada dimesion tiene nuestro array
# Out:
# (4,)

# %%
np.random.randint(10, 20, 6)  #array unidimensional
# Out:
# array([14, 16, 11, 12, 11, 14])

# %%
np.random.randint(10, 20, (3, 4)) #random sublibreria de numpy
#randint me genera enteros aleatorios. Tengo que pasarle el entero mas pequeño que
#quiero generar, el mas grande y podemos pasarle el tamaño del array que queremos generar
#si le paso tupla, dos dimensiones
# Out:
# array([[16, 18, 18, 12],
#        [19, 14, 14, 11],
#        [15, 15, 19, 18]])

# %%
names(np.random)
# Out:
# ['BitGenerator', 'Generator', 'MT19937', 'PCG64', 'PCG64DXSM', 'Philox', 'RandomState', 'SFC64', 'SeedSequence', 'beta', 'binomial', 'bit_generator', 'bytes', 'chisquare', 'choice', 'default_rng', 'dirichlet', 'exponential', 'f', 'gamma', 'geometric', 'get_bit_generator', 'get_state', 'gumbel', 'hypergeometric', 'laplace', 'logistic', 'lognormal', 'logseries', 'mtrand', 'multinomial', 'multivariate_normal', 'negative_binomial', 'noncentral_chisquare', 'noncentral_f', 'normal', 'pareto', 'permutation', 'poisson', 'power', 'rand', 'randint', 'randn', 'random', 'random_integers', 'random_sample', 'ranf', 'rayleigh', 'sample', 'seed', 'set_bit_generator', 'set_state', 'shuffle', 'standard_cauchy', 'standard_exponential', 'standard_gamma', 'standard_normal', 'standard_t', 'test', 'triangular', 'uniform', 'vonmises', 'wald', 'weibull', 'zipf']

# %%
generator = np.random.Generator(np.random.PCG64()) #es una funcion que nos permite crear un generador de  nºs aleatorios
generator
# Out:
# Generator(PCG64) at 0x7F92362889E0

# %%
names(generator)
# Out:
# ['beta', 'binomial', 'bit_generator', 'bytes', 'chisquare', 'choice', 'dirichlet', 'exponential', 'f', 'gamma', 'geometric', 'gumbel', 'hypergeometric', 'integers', 'laplace', 'logistic', 'lognormal', 'logseries', 'multinomial', 'multivariate_hypergeometric', 'multivariate_normal', 'negative_binomial', 'noncentral_chisquare', 'noncentral_f', 'normal', 'pareto', 'permutation', 'permuted', 'poisson', 'power', 'random', 'rayleigh', 'shuffle', 'spawn', 'standard_cauchy', 'standard_exponential', 'standard_gamma', 'standard_normal', 'standard_t', 'triangular', 'uniform', 'vonmises', 'wald', 'weibull', 'zipf']

# %%
np.random.randint(10, 20, 5) #creacion de arrays de nºs enteros aleatorios con metodo antiguo
# Out:
# array([10, 17, 19, 16, 15])

# %%
generator.integers(10, 20, 5) #creacion de arrays de nºs enteros aleatorios con metodo nuevo
# Out:
# array([15, 18, 14, 10, 10])

# %%
a = generator.integers(10, 20, 5)
a
# Out:
# array([19, 16, 11, 12, 19])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a[4]
# Out:
# 19

# %%
a[-1]
# Out:
# 19

# %%
a[2:4]
# Out:
# array([11, 12])

# %%
a = generator.integers(0, 20, size = (4, 5)) #De dos dimensiones
a
# Out:
# array([[ 7,  7,  9, 10,  8],
#        [17,  8,  8,  5, 15],
#        [ 4, 12, 14, 17, 13],
#        [ 7,  5,  5, 18,  3]])

# %%
a[2, 1]
# Out:
# 12

# %%
a[2, 1:3]
# Out:
# array([12, 14])

# %%
a[2, 0:5]
# Out:
# array([ 4, 12, 14, 17, 13])

# %%
a[0:2, 2:3]
# Out:
# array([[9],
#        [8]])

# %%
a[1:3, 1:4]
# Out:
# array([[ 8,  8,  5],
#        [12, 14, 17]])

# %%
#Imagenes Jpgs tienen 1 capa (blanco y negro) o 3 capas(rgb)
# png 1 capa (blanco y negro), 3 capas (rgb) o 4 (1 de transparencia + 3 rpg)

# %%
#Las imgs tienen 3 dimensiones. Ancho, alto y capas

# %%
# ":" se referencias todos los valores de un eje
# a[:,:,2] todos los valores de x y y de la capa 3

# %%
a.shape
# Out:
# (4, 5)

# %% [markdown]
# # MatplotLib

# %%
#Nos sirve para leer imagenes de nuestro disco

# %%
sunset = plt.imread("sunset.png") #me lee la img y la guardo en variable

# %%
type(sunset)
# Out:
# numpy.ndarray

# %%
sunset.ndim
# Out:
# 3

# %%
sunset.dtype
# Out:
# dtype('float32')

# %%
sunset.shape #600 eje 0, vertical. 800 eje 1 horizontal. 4 eje 2. 4 capas
# Out:
# (600, 800, 4)

# %%
plt.imshow(sunset); #metodo de muestra de img

# %%
#Tiene 4 capas, entre ellas, una de transparencia

# %%
sunset.max() #el valor mas elevado contenido en el array... aca es 1
# Out:
# 1.0

# %%
sunset.min() #el valor menor es 0
# Out:
# 0.0

# %%
#la codificacion de las imgs puede darse de dos formas.. o bien representadas con numeros reales entre 0 a 1 o bien con numeros enteros entre 0 y 255.
#en esta img son nºs reales en esta fotografia
#Si hay un 1 en la capa de transparencia, lo que quiere decir es que el punto en que existe ese valor es opaco, se ve un color
#En cambio si es 0, es transparente

# %%
a
# Out:
# array([[ 7,  7,  9, 10,  8],
#        [17,  8,  8,  5, 15],
#        [ 4, 12, 14, 17, 13],
#        [ 7,  5,  5, 18,  3]])

# %%
a.flatten() #Nos devuelve un array aplanado.
#Lo transforma en una sola dimensión. aca transformo un array de dos, tres dimensiones, en uno de una.
# Out:
# array([ 7,  7,  9, 10,  8, 17,  8,  8,  5, 15,  4, 12, 14, 17, 13,  7,  5,
#         5, 18,  3])

# %%
plt.hist(a.flatten()); #Creo histograma, para ver distribución de ceros y unos de mi fotografía

# %%
plt.hist(a.flatten(), bins = 4);

# %%
plt.hist(a.flatten(), bins = 20);

# %%
plt.hist(sunset.flatten()); #10 bins es el valor por defecto

# %%
plt.hist(sunset.flatten(), bins = 10); #Por defecto, son 10 bins. Si no especifico bins, son 10
#Los bins son las "plumitas" o las barras de la grafica

# %%
plt.hist(sunset.flatten(), bins = 50);

# %%
#La barra alta, que es alta acumulacion de "unos" es la capa de transparencia. Porque la capa de transparencia es
#todo casi unos

# %%
plt.hist(sunset[:,:,0:3].flatten(), bins = 50);
# [:,:,:3]

# %%
b = sunset.copy()

# %%
plt.imshow(b);

# %%
plt.hist(b[:,:, -1].flatten(), bins = 50);

# %%
b[200:400, :, -1] = 0.5 #Si le paso uno, la capa de transparencia es transparente y muestra el color
#si le paso cero, blaquea totalmente la img

# %%
plt.imshow(b);

# %%
sun = b[480:520, 450:500]

# %%
plt.imshow(sun);

# %%
plt.imshow(sunset);

# %%
red = sunset[:, :, 0]

# %%
plt.imshow(red); #esto serían ahora dos dimensiones. Extraje una capa

# %%
red.ndim #dos dimensiones, porque solo me muestra una capa, la de rojos. Las otras dos dimensiones es alto por ancho
# Out:
# 2

# %%
#no me muestra una capa de "rojos", ya que con una estructura bidimensional no puedo mostrar colores. Solo 
#escala de grises. Entonces matplotlib asigna colores en base a su criterio pero no son rojos, ni blancos ni negros

# %%
plt.imshow(red, cmap = "summer"); #aca le digo que me haga una asignación de colores distinta a la anterior

# %%
plt.imshow(red, cmap = "Reds"); #aca le digo que me asigne con colores rojizos

# %%
plt.imshow(red, cmap = "Reds_r"); #esto son asignaciones de colores arbitrarios de matplotlib

# %%
plt.imshow(red, cmap = "gray");

# %%
import math

# %%
n = 5
m = [generator.random() for _ in range(n)]
m
# Out:
# [0.15493948380794398,
#  0.7009633137945969,
#  0.17492019409748505,
#  0.8379422908809611,
#  0.14409167719953075]

# %%
# %%timeit #esto mide el tiempo que se tarda en ejecutarse. Ejecuta esto varias veces y me dice el tiempo medio
p = []
for v in m: #con bucle for
    p.append(math.log(v))
p
# Out:
# 52 µs ± 784 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
n = 1000
m = [generator.random() for _ in range(n)]

# %%
# %%timeit #esto mide el tiempo que se tarda en ejecutarse. Ejecuta esto varias veces y me dice el tiempo medio
p = [] 
for v in m: #con bucle for
    p.append(math.log(v))
# Out:
# 53.5 µs ± 2.56 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
p = [math.log(v) for v in m]  #con list comprehension
# Out:
# 53.5 µs ± 786 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
m = np.array(m) #ahora con array numpy

# %%
# %%timeit
p = np.log(m)
# Out:
# 4.6 µs ± 1.3 µs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
#Lo mas eficiente casi 30 veces es el array numpy, sobre el bucle for y el list comprehension

# %%
a
# Out:
# array([[ 7,  7,  9, 10,  8],
#        [17,  8,  8,  5, 15],
#        [ 4, 12, 14, 17, 13],
#        [ 7,  5,  5, 18,  3]])

# %%
a = generator.integers(1, 10, size = (4, 6))
a
# Out:
# array([[1, 4, 6, 2, 5, 9],
#        [5, 7, 4, 3, 8, 3],
#        [8, 2, 5, 3, 9, 7],
#        [3, 9, 2, 7, 8, 7]])

# %%
np.log(a) #np.log es una funcion universal, pq devuelve un array con el mismo tamaño que el original
# Out:
# array([[0.        , 1.38629436, 1.79175947, 0.69314718, 1.60943791,
#         2.19722458],
#        [1.60943791, 1.94591015, 1.38629436, 1.09861229, 2.07944154,
#         1.09861229],
#        [2.07944154, 0.69314718, 1.60943791, 1.09861229, 2.19722458,
#         1.94591015],
#        [1.09861229, 2.19722458, 0.69314718, 1.94591015, 2.07944154,
#         1.94591015]])

# %%
b = generator.integers(1, 10, size = (4, 6))
b
# Out:
# array([[8, 7, 1, 9, 4, 8],
#        [3, 8, 3, 7, 3, 9],
#        [6, 6, 9, 9, 8, 7],
#        [7, 2, 2, 5, 6, 1]])

# %%
np.add(a, b) #funcion universal. "Element Wise" Cuando algo se aplica elemento por elemento
# Out:
# array([[ 9, 11,  7, 11,  9, 17],
#        [ 8, 15,  7, 10, 11, 12],
#        [14,  8, 14, 12, 17, 14],
#        [10, 11,  4, 12, 14,  8]])

# %%
np.subtract(a, b)
# Out:
# array([[-7, -3,  5, -7,  1,  1],
#        [ 2, -1,  1, -4,  5, -6],
#        [ 2, -4, -4, -6,  1,  0],
#        [-4,  7,  0,  2,  2,  6]])

# %%
np.multiply(a, b)
# Out:
# array([[ 8, 28,  6, 18, 20, 72],
#        [15, 56, 12, 21, 24, 27],
#        [48, 12, 45, 27, 72, 49],
#        [21, 18,  4, 35, 48,  7]])

# %%
np.sqrt(a)
# Out:
# array([[1.        , 2.        , 2.44948974, 1.41421356, 2.23606798,
#         3.        ],
#        [2.23606798, 2.64575131, 2.        , 1.73205081, 2.82842712,
#         1.73205081],
#        [2.82842712, 1.41421356, 2.23606798, 1.73205081, 3.        ,
#         2.64575131],
#        [1.73205081, 3.        , 1.41421356, 2.64575131, 2.82842712,
#         2.64575131]])

# %%
np.square(a)
# Out:
# array([[ 1, 16, 36,  4, 25, 81],
#        [25, 49, 16,  9, 64,  9],
#        [64,  4, 25,  9, 81, 49],
#        [ 9, 81,  4, 49, 64, 49]])

# %%
np.sin(a)
# Out:
# array([[ 0.84147098, -0.7568025 , -0.2794155 ,  0.90929743, -0.95892427,
#          0.41211849],
#        [-0.95892427,  0.6569866 , -0.7568025 ,  0.14112001,  0.98935825,
#          0.14112001],
#        [ 0.98935825,  0.90929743, -0.95892427,  0.14112001,  0.41211849,
#          0.6569866 ],
#        [ 0.14112001,  0.41211849,  0.90929743,  0.6569866 ,  0.98935825,
#          0.6569866 ]])

# %%
a
# Out:
# array([[1, 4, 6, 2, 5, 9],
#        [5, 7, 4, 3, 8, 3],
#        [8, 2, 5, 3, 9, 7],
#        [3, 9, 2, 7, 8, 7]])

# %%
b
# Out:
# array([[8, 7, 1, 9, 4, 8],
#        [3, 8, 3, 7, 3, 9],
#        [6, 6, 9, 9, 8, 7],
#        [7, 2, 2, 5, 6, 1]])

# %%
np.equal(a, b)
# Out:
# array([[False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False,  True],
#        [False, False,  True, False, False, False]])

# %%
np.greater(a, b)
# Out:
# array([[False, False,  True, False,  True,  True],
#        [ True, False,  True, False,  True, False],
#        [ True, False, False, False,  True, False],
#        [False,  True, False,  True,  True,  True]])

# %%
np.greater_equal(a, b)
# Out:
# array([[False, False,  True, False,  True,  True],
#        [ True, False,  True, False,  True, False],
#        [ True, False, False, False,  True,  True],
#        [False,  True,  True,  True,  True,  True]])

# %%
np.less(a, b)
# Out:
# array([[ True,  True, False,  True, False, False],
#        [False,  True, False,  True, False,  True],
#        [False,  True,  True,  True, False, False],
#        [ True, False, False, False, False, False]])

# %%
plt.imshow(sunset);

# %%
plt.imshow(sunset[:, :, 0:3] / 2); #(/4 es 0.25)

# %%
sunset = plt.imread("sunset.png")

# %%
dog = plt.imread("dog.jpg")

# %%
dog.ndim

# %%
plt.imshow(np.concatenate((sunset[:, :, 0:3], dog), axis = 0));

# %%
sunset.shape

# %%
dog.shape

# %%
plt.imshow(np.concatenate((sunset[:, :, 0:3], dog / 255), axis = 0));

# %%
from scipy.io import wavfile

# %%
names(wavfile)

# %%
wavfile.read("toy_story.wav")

# %%
freq, data = wavfile.read("toy_story.wav")

# %%
freq

# %%
data

# %%
data.dtype

# %%
data.ndim

# %%
data.shape #muestreo + dos canales (estereo)

# %%
data.shape[0] / freq #duracion del sonido

# %%
left = data[:, 0] #xtraemos todo el canal izquierdo

# %%
right = data[:, 1] #xtraemos todo el canal izquierdo

# %%
plt.plot(left);

# %%
plt.plot(right);

# %% [markdown]
# # Pandas

# %%
# Ventas de mis tiendas.

# %%
lisboa = np.array([2, 4, 5])
madrid = np.array([1, 4, 3])

# %%
lisboa + madrid

# %%
#El tema de numPy es que actua por posicion. Entonces me suma verticalmente, como veo arriba
# pero si en lisboa fuera enero, febrero y marzo pero en madrid enero, marzo y abril. Pues me haria la suma incorrectamente

# %%
#Pandas me ofrede dos estructuras nuevas que resuelven este problema

#Series: 1 Dimensión
    #Se basan en un array numPy de una dimensión
#DataFrame: 2 Dimensiones.
    #Se basan en un array numPy de una dimensión
#No trabaja con mas dimensiones

# %%
import pandas as pd

# %%
pd.Series([2, 4, 6, 8, 10])

# %%
#Etiqueta implícita. Es la posición de cada elemento. La primer barra (columna) de la izquierda de la Serie

# %%
pd.Series([2, 4, 6, 8, 10], index = ["a", "b", "c", "d", "e"])

# %%
a = pd.Series([2, 4, 6], index = ["ene", "feb", "mar"])
a

# %%
#Estos son etiquetas explícitas. Porque las indico yo.

# %%
lisboa = pd.Series([2, 4, 6], index = ["ene", "feb", "mar"])
lisboa

# %%
madrid = pd.Series([3, 2, 3], index = ["mar", "ene", "feb"])
madrid

# %%
lisboa + madrid

# %%
#Pandas analiza las etiquetas explícitas. Las alinea y a raiz de ahí, hace la operación solicitada

# %%
a = pd.Series([2, 4, 6])
a

# %%
b = pd.Series([3, 2, 3])
b

# %%
a + b

# %%
#las etiquetas implicitas, al final trabajan por posición. Y haría lo mismo que NunPy.
#Lo inteligente es usar ,las explícitas que es para lo que se usa Pandas

# %%
# pd.DataFrame(data = generator.integers(0, 10, size = (4, 6)))

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
